# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st


# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combine_df = pd.merge(study_results,mouse_metadata, how = 'left', on = 'Mouse ID')

# Display the data table for preview

combine_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
number_of_mice = len(combine_df['Mouse ID'].unique())
number_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dublicate_mice = combine_df.loc[combine_df.duplicated(subset=['Mouse ID','Timepoint']),'Mouse ID'].unique()
dublicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dublicate_mice_df = combine_df.loc[combine_df['Mouse ID']=='g989']

dublicate_mice_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# 1380     g989         30           59.082294                 1     Propriva
# 1592     g989         35           62.570880                 2     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# 329   Female          21          26
# 360   Female          21          26
# 620   Female          21          26
# 681   Female          21          26
# 815   Female          21          26
# 869   Female          21          26
# 950   Female          21          26
# 1111  Female          21          26
# 1195  Female          21          26
# 1380  Female          21          26
# 1592  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_combine_df = combine_df[combine_df['Mouse ID'].isin(dublicate_mice) == False]
clean_combine_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
cleandf_mice_num = len(clean_combine_df['Mouse ID'].value_counts())
cleandf_mice_num
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume
#for each regimen
regimen_mean = clean_combine_df.groupby('Drug Regimen').mean()['Tumor Volume (mm3)']
regimen_median = clean_combine_df.groupby('Drug Regimen').median()['Tumor Volume (mm3)']
regimen_variance = clean_combine_df.groupby('Drug Regimen').var()['Tumor Volume (mm3)']
regimen_std = clean_combine_df.groupby('Drug Regimen').std()['Tumor Volume (mm3)']
regimen_sem = clean_combine_df.groupby('Drug Regimen').sem()['Tumor Volume (mm3)']
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

sum_stats_df = pd.DataFrame({
                        'Mean Tumor Volume':regimen_mean,
                        'Median Tumor Volume':regimen_median,
                        'Variance Tumor Volume':regimen_variance,
                        'Std.Dev Tumor Volume':regimen_std,
                        'Sem Tumor Volume':regimen_sem
                            })
sum_stats_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Variance Tumor Volume  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Std.Dev Tumor Volume  Sem Tumor Volume
# Drug Regimen
# Capomulin                 4.994774          0.329346
# Ceftamin                  6.268188          0.469821
# Infubinol                 6.567243          0.492236
# Ketapril                  8.279709          0.603860
# Naftisol                  8.134708          0.596466
# Placebo                   7.821003          0.581331
# Propriva                  6.622085          0.544332
# Ramicane                  4.846308          0.320955
# Stelasyn                  7.710419          0.573111
# Zoniferol                 6.966589          0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
sum_stats_df_2 = clean_combine_df.groupby(['Drug Regimen'])[['Tumor Volume (mm3)']].agg(['mean','median','var','std','sem'])
sum_stats_df_2
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
mice_count = clean_combine_df['Drug Regimen'].value_counts()
plot_pandas = mice_count.plot.bar(color = 'tab:blue', xlabel = 'Drug Regimen', ylabel = 'Number of mice Tested')
plt.title('NUmber of mice per treatment')
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
x_axis = mice_count.index.values
y_axis = mice_count.values
plt.bar(x_axis,y_axis, color = 'tab:blue',align = 'center')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of mice Tested')
plt.title('NUmber of mice per treatment')
plt.xticks(rotation= 'vertical' )
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
dist_sex_panda = clean_combine_df['Sex'].value_counts()
dist_sex_panda.plot(kind = 'pie',autopct = '%1.1f%%')
plt.title('Male VS female')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sizes = dist_sex_panda.values

labels = dist_sex_panda.index

plt.pie(sizes,labels = labels, autopct = '%1.1f%%')
plt.title('Male VS Female')
plt.ylabel('Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
timepoint_last = combine_df.groupby(['Mouse ID']).max()['Timepoint']
timepoint_last_df = pd.DataFrame(timepoint_last)


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

merged_df = pd.merge(timepoint_last_df.reset_index(),clean_combine_df, how = 'left', on = ('Mouse ID','Timepoint'))
merged_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419               2.0    Infubinol
# 1       a251         45           65.525743               1.0    Infubinol
# 2       a262         45           70.717621               4.0      Placebo
# 3       a275         45           62.999356               3.0     Ceftamin
# 4       a366         30           63.440686               1.0     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 244     z435         10           48.710661               0.0     Propriva
# 245     z578         45           30.638696               0.0     Ramicane
# 246     z581         45           62.754451               3.0    Infubinol
# 247     z795         45           65.741070               3.0     Naftisol
# 248     z969         45           73.867845               4.0     Naftisol
#
#         Sex  Age_months  Weight (g)
# 0    Female        20.0        23.0
# 1    Female        21.0        25.0
# 2    Female        17.0        29.0
# 3    Female        20.0        28.0
# 4    Female        16.0        29.0
# ..      ...         ...         ...
# 244  Female        12.0        26.0
# 245    Male        11.0        16.0
# 246  Female        24.0        25.0
# 247  Female        13.0        29.0
# 248    Male         9.0        30.0
#
# [249 rows x 8 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatments = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
total_tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatments:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_vol = merged_df.loc[merged_df['Drug Regimen'] == drug ,'Tumor Volume (mm3)']

     # add subset 
    total_tumor_vol.append(tumor_vol)
    
    # Determine outliers using upper and lower bounds
    quartiles = tumor_vol.quantile([.25, .5, .75])
    upperq = quartiles[.75]
    lowerq = quartiles[.25]
    IQR = upperq - lowerq
    IQR
    lower_bound = lowerq - (1.5*IQR)
    upper_bound = upperq + (1.5*IQR)
    outliers = tumor_vol.loc[(tumor_vol>upper_bound)|(tumor_vol<lower_bound)]
    print(f"{drug}\'s potential outliers:{outliers}")
# Out:
# Capomulin's potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers:31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers:Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
red_dot = dict(markerfacecolor = 'red')
plt.boxplot(total_tumor_vol,labels = treatments,flierprops = red_dot)
plt.ylabel('Final Tumor value(mm3)')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
Capomulin_df = clean_combine_df.loc[clean_combine_df['Drug Regimen'] =='Capomulin']
for_mouse_df = Capomulin_df.loc[Capomulin_df['Mouse ID']== 'l509']
x_axis = for_mouse_df['Timepoint']
y_axis = for_mouse_df['Tumor Volume (mm3)']
plt.plot(x_axis,y_axis,color = 'b', linewidth = 2)
plt.title('Capomulin treatment of mouse l509')
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
avg_tumor_val_df = Capomulin_df.groupby(['Mouse ID']).mean()
avg_tumor_val = avg_tumor_val_df['Tumor Volume (mm3)']
avg_weight = avg_tumor_val_df['Weight (g)']
plt.scatter(avg_weight,avg_tumor_val, marker = 'o', color = 'b')
plt.xlabel('Weight (g)')
plt.ylabel('average Tumor Volume (mm3)')

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(avg_weight,avg_tumor_val)
print(f'The corrolation between mouse weight and the average tumor volume is {round(correlation[0],2)}')
(slope,intercept,rvalue,pvalue,stderr)=st.linregress(avg_weight,avg_tumor_val)
regress_values = avg_weight*slope+intercept

plt.scatter(avg_weight,avg_tumor_val, marker = 'o', color = 'b')
plt.plot(avg_weight,regress_values, color = 'r')
plt.xlabel('Weight (g)')
plt.ylabel('average Tumor Volume (mm3)')
plt.show()
# Out:
# The corrolation between mouse weight and the average tumor volume is 0.84
